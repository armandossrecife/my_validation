ce797708699bfffa6bb6c1b3fa1', 'fde22a8496a160fc746c6f193dea3f29d113c6e3', '6aaf859d22bd0e3ab27a3e74d7b9402521d10573', 'dbb1d8b83d2ee5c5a38c55834a70cd21a2dd2ad0', '8dbb48a23fc6170afd5c3c855e8d385297042e57', '849987e5dd1ad35a17711c19a3e51c5eefeae6f3', 'ab28b771e367d8fa4f9591fb88cb9c29ec41c25a', '12b26b641b36a4ad6d21face946300128cb7be59', '4f8d56aaf60f99abe643e79c6c4940a571289a86', '1ad0117932ae73603b963860c92c0980a3572b9e', '09054fc4a85bcdef9e19e589be368d0e9cf0de41', '4318eba4a34ad64b1dad549ba94dadd155149b4a', '2b84cd60ba775a2e0106a3c6f577ea78b05b143b', '10c998b0bc9728276a738ed24d20c6fc82c6365a', '499e39e52c392fcc6d897a526afbbd3b144121e2', 'f47b370573d5a2bcb5a000c1adce0bbf7d40f5b1', 'b4e35fe8a355c0fd5fe8935ab583e2886121946b', 'ffee8b442f57b38d57a59745b9062e8d963c65ba', '406a34294befca4ba2de4b728c86f64b96a94945', '7c3bb401007b4047c540287b53b435b20d3161c0', '2769298cf64a10cd74320ad132b3677bac20a6cc', 'd0c95146c37f96ca69e1fe82c4b2fe9208f8184e', '2ea5d1420bbbf90bd151e19a75e6ca33c773f1f4', '03b19b9da4d50c3bb8985f930e93596c7d994d26', '060817552de9b8f2f1c66a3146f74c51233f943c', 'fca3b615eb869330633b71978843a682bfa8ab49', '2cc17a2fa06b86fef58bd26141d29bb5cb0d715d', 'ee768a28d6abb986fa1085550df43d0de0b6580f', '596ee316874894ad0342475d8f242913bd507cd1', '76f612600d291dfb4152b90a3dbfc9ce8ea2e1a5', 'c140d73feca4a18044701ebf1df2859ec8c33207', 'ed924cddac90b96bdc47b215852a68155d818bcd', '901956d4ddb6a0ea9fe5fedf39732117ab68f087']

# %% [markdown]
# # Keywords about SATD (Self-admitted Technical Debt)
#
# Self-Admitted Technical Debt (SATD) refers to situations where the developers are aware that the current implementation is not optimal and write comments alerting of the problems [3]

# %% [markdown]
# [1] Rantala, Leevi, and Mika Mäntylä. "Predicting technical debt from commit contents: reproduction and extension with automated feature selection." Software Quality Journal 28 (2020): 1551-1579. ~> https://link.springer.com/article/10.1007/s11219-020-09520-3
#
# [2] Li, Yikun, Mohamed Soliman, and Paris Avgeriou. "Automatic identification of self-admitted technical debt from four different sources." Empirical Software Engineering 28, no. 3 (2023): 1-38. ~> https://link.springer.com/article/10.1007/s10664-023-10297-9
#
# [3] Potdar, Aniket, and Emad Shihab. "An exploratory study on self-admitted technical debt." In 2014 IEEE International Conference on Software Maintenance and Evolution, pp. 91-100. IEEE, 2014. ~> https://ieeexplore.ieee.org/abstract/document/6976075

# %%
satd_keywords_1_2 = {
    "typo", "unused import", "error message", "comment", "logging", "javadoc", "minor", "update",
    "debug", "code cleanup", "formatting", "more tests", "documentation", "work in progress",
    "improvement", "rename", "support for", "header", "interface", "annotation", "naming",
    "tidy up", "files", "extension point", "exception", "handling", "test", "output", "cast",
    "simplify", "findbugs", "leak", "implementation", "unused code", "API", "refactoring",
    "checkstyle errors", "redundant", "deprecated code", "constructor", "endpoints", "flaky",
    "unused", "unnecessary", "confusing", "ugly", "simplify", "too much", "not used", "more readable",
    "more efficient", "dead code", "infinite loop", "too long", "not implemented", "less verbose",
    "more robust", "speed up", "get rid of", "not thread safe", "clean up code", "not done yet",
    "avoid extra seek", "reduce duplicate code", "no longer needed", "not supported yet",
    "documentation doesn't match", "short term solution", "spurious error messages", "it'd be nice",
    "please add a test", "would significantly improve", "performance", "makes it much easier",
    "avoid calling it twice", "takes a long time", "good to have coverage",
    "makes it very hard", "patch doesn't apply cleanly", "it's not perfectly documented",
    "need to update documentation", "make it less brittle", "documentation does not mention",
    "wastes a lot of space", "there is no unit test", "lead to huge memory allocation",
    "test doesn't add much value", "some holes in the doc", "by hard coding instead of",
    "should be updated to reflect", "more tightly coupled than ideal", "any chance of a test",
    "should improve a bit by", "solution won't be really satisfactory", "misleading",
    "too long", "please add a test", "there is no unit test", "any chance of a test",
    "good to have coverage", "test doesn't add much value", "flaky",
}

satd_keywords_diff_3 = {'TODO', 'FIXME', 'refactor', 'refact', 'hack', 'workaround', 'technical debt', 'cleanup', 'clean', 'fix'}

# Extra keywords
extra_keywords = set([
    "architectural issue", "architectural smell", "architectural debt", "design debt", "code rot", "spaghetti code",
    "quick fix", "temporary solution", "workaround", "hack", "technical kludge", "inconsistency", "race condition", "performance",
    "scalability", "reliability", "maintainability", "code duplication", "code complexity", "tight coupling", "fragile code",
    "magic numbers", "magic strings", "lack of modularity", "lack of encapsulation", "lack of abstraction", "lack of documentation",
    "lack of testing", "complexity", "duplication", "modularity", "encapsulation", "design", "violation", "dependency",
    "dependencies", "refactoring", "cyclic dependency", "unstable", "cross-module",
    "code smell", "architectural problem", "design issue", "system design problem",
    "technical debt due to architectural issues", "code debt", "technical debt due to design issues", "design flaws",
    "disorganized code", "difficult to maintain code", "poorly structured code", "complex code",
    "concurrency issue", "multithreading issue", "synchronization issue",
    "speed", "throughput", "latency", "response time",
    "scalability issue", "ability to handle increased load",
    "dependability", "trustworthiness", "fault tolerance", "robustness",
    "ease of maintenance", "maintainability issue", "ability to evolve",
    "code redundancy", "repeated code",
    "code difficulty", "complex code", "difficult to understand code",
    "code entanglement", "code interdependencies", "complex code relationships",
    "delicate code", "brittle code", "easy to break code",
    "literal values", "hard-coded values", "undocumented values",
    "literal strings", "hard-coded strings", "undocumented strings",
    "monolithic code", "lack of separation of concerns", "lack of cohesion",
    "exposed internal state", "lack of information hiding",
    "concrete code", "lack of generalization",
    "undocumented code", "poorly documented code", "lack of code comments",
    "untested code", "poorly tested code", "lack of test cases",
    "code complexity", "cyclomatic complexity", "cognitive complexity",
    "code dependencies", "module dependencies", "system dependencies",
    "code restructuring", "code improvement", "code simplification",
    "circular dependency", "indirect dependency",
    "buggy code", "flaky code", "unreliable code",
    "inter-module", "module-to-module"
])

extra_keywords_td = set([
    "anti-pattern", "bad practice", "code smell", "design smell", "technical debt",
    "wrong solution", "poor solution", "ineffective solution", "inefficient solution", "suboptimal solution",
    "wrong way", "poor way", "ineffective way", "inefficient way", "suboptimal way",
    "code defect", "code problem", "code issue", "code flaw",
    "design defect", "design problem", "design issue", "design flaw",
    "code debt", "design debt", "architectural debt", "implementation debt", "testing debt", "documentation debt"
])

my_satd_keywords = satd_keywords_diff_3.union(satd_keywords_1_2)

my_satd_aux = my_satd_keywords.union(extra_keywords)

final_satd_keywords = my_satd_aux.union(extra_keywords_td)

# Sort the set of strings in ascending order.
sorted_my_satd_keywords = sorted(final_satd_keywords)

print(f'Qtd de sorted_my_satd_keywords: {len(sorted_my_satd_keywords)}')
# Print the sorted set of strings.
list_temp = []
for word in sorted_my_satd_keywords:
  list_temp.append(word)

print(list_temp)
# Out:
# Qtd de sorted_my_satd_keywords: 235
# ['API', 'FIXME', 'TODO', 'ability to evolve', 'ability to handle increased load', 'annotation', 'anti-pattern', 'any chance of a test', 'architectural debt', 'architectural issue', 'architectural problem', 'architectural smell', 'avoid calling it twice', 'avoid extra seek', 'bad practice', 'brittle code', 'buggy code', 'by hard coding instead of', 'cast', 'checkstyle errors', 'circular dependency', 'clean', 'clean up code', 'cleanup', 'code cleanup', 'code complexity', 'code debt', 'code defect', 'code dependencies', 'code difficulty', 'code duplication', 'code entanglement', 'code flaw', 'code improvement', 'code interdependencies', 'code issue', 'code problem', 'code redundancy', 'code restructuring', 'code rot', 'code simplification', 'code smell', 'cognitive complexity', 'comment', 'complex code', 'complex code relationships', 'complexity', 'concrete code', 'concurrency issue', 'confusing', 'constructor', 'cross-module', 'cyclic dependency', 'cyclomatic complexity', 'dead code', 'debug', 'delicate code', 'dependability', 'dependencies', 'dependency', 'deprecated code', 'design', 'design debt', 'design defect', 'design flaw', 'design flaws', 'design issue', 'design problem', 'design smell', 'difficult to maintain code', 'difficult to understand code', 'disorganized code', 'documentation', 'documentation debt', 'documentation does not mention', "documentation doesn't match", 'duplication', 'ease of maintenance', 'easy to break code', 'encapsulation', 'endpoints', 'error message', 'exception', 'exposed internal state', 'extension point', 'fault tolerance', 'files', 'findbugs', 'fix', 'flaky', 'flaky code', 'formatting', 'fragile code', 'get rid of', 'good to have coverage', 'hack', 'handling', 'hard-coded strings', 'hard-coded values', 'header', 'implementation', 'implementation debt', 'improvement', 'inconsistency', 'indirect dependency', 'ineffective solution', 'ineffective way', 'inefficient solution', 'inefficient way', 'infinite loop', 'inter-module', 'interface', "it'd be nice", "it's not perfectly documented", 'javadoc', 'lack of abstraction', 'lack of code comments', 'lack of cohesion', 'lack of documentation', 'lack of encapsulation', 'lack of generalization', 'lack of information hiding', 'lack of modularity', 'lack of separation of concerns', 'lack of test cases', 'lack of testing', 'latency', 'lead to huge memory allocation', 'leak', 'less verbose', 'literal strings', 'literal values', 'logging', 'magic numbers', 'magic strings', 'maintainability', 'maintainability issue', 'make it less brittle', 'makes it much easier', 'makes it very hard', 'minor', 'misleading', 'modularity', 'module dependencies', 'module-to-module', 'monolithic code', 'more efficient', 'more readable', 'more robust', 'more tests', 'more tightly coupled than ideal', 'multithreading issue', 'naming', 'need to update documentation', 'no longer needed', 'not done yet', 'not implemented', 'not supported yet', 'not thread safe', 'not used', 'output', "patch doesn't apply cleanly", 'performance', 'please add a test', 'poor solution', 'poor way', 'poorly documented code', 'poorly structured code', 'poorly tested code', 'quick fix', 'race condition', 'reduce duplicate code', 'redundant', 'refact', 'refactor', 'refactoring', 'reliability', 'rename', 'repeated code', 'response time', 'robustness', 'scalability', 'scalability issue', 'short term solution', 'should be updated to reflect', 'should improve a bit by', 'simplify', "solution won't be really satisfactory", 'some holes in the doc', 'spaghetti code', 'speed', 'speed up', 'spurious error messages', 'suboptimal solution', 'suboptimal way', 'support for', 'synchronization issue', 'system dependencies', 'system design problem', 'takes a long time', 'technical debt', 'technical debt due to architectural issues', 'technical debt due to design issues', 'technical kludge', 'temporary solution', 'test', "test doesn't add much value", 'testing debt', 'there is no unit test', 'throughput', 'tidy up', 'tight  ...

# %% [markdown]
# # Scripts e Funções de apoio

# %% [markdown]
# ## Instala dependências

# %%
print('Install Pydriller.')
# !pip install pydriller > install_pydriller.log
print('Install gitpython.')
# !pip3 install gitpython > install_gitpython.log
print('All depenpencies installed!')
# !cat *.log > install.log
print('Details in install.log')
# Out:
# Install Pydriller.
# Install gitpython.
# All depenpencies installed!
# Details in install.log

# %%
from pydriller import Repository
import tqdm
import os
import re
from datetime import datetime, timedelta
import pandas as pd

# %%
url_to_repository = 'https://github.com/apache/activemq.git'
path_to_repository = 'activemq'
os.environ['MY_REPOSITORY'] = url_to_repository

# %% [markdown]
# ## Funções

# %%
class SATDCommitAnalyzer:
    def __init__(self, path_to_repository):
        self.path_to_repository = path_to_repository

    @staticmethod
    def is_java_comment(line):
        """Checks if a line is a single-line Java comment.
        Args:
          line: The line to check.
        Returns:
          True if the line is a single-line Java comment, False otherwise.
        """
        # Regular expression pattern to match Java comments
        comment_pattern = r'^\s*//|^\s*/\*|^\s*\*|^\s*\*/'
        # Use the re.match function to check if the line matches the comment pattern
        return bool(re.match(comment_pattern, line))

    def analyze_commits_for_satd(self, start_date, end_date, satd_keywords):
        """Analyzes commits for SATD by checking if the commit message contains any of the specified SATD keywords.
        Args:
          start_date: The start date of the date range to analyze commits within.
          end_date: The end date of the date range to analyze commits within.
          satd_keywords: A list of SATD keywords to search for in commit messages.
        Returns:
          A tuple containing two sets:
            * A set of commit hashes that contain SATD keywords in their commit messages.
            * A dictionary mapping commit hashes to their associated commit messages.
        """
        # Initialize sets to store commits and their associated SATD keywords
        commits_with_satd = set()
        dict_commit_msg = {}

        # Traverse commits within the specified date range
        print('Aguarde...')
        my_traverser_commits = Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits()
        total_commits = len(list(my_traverser_commits))

        for commit in tqdm.tqdm(Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits(), total=total_commits, desc="Progress SATD message commit analysis"):
            for keyword in satd_keywords:
                if keyword in commit.msg:
                    commits_with_satd.add(commit.hash)
                    dict_commit_msg[commit.hash] = commit.msg

        return commits_with_satd, dict_commit_msg

    def analyze_commits_for_no_satd(self, start_date, end_date, satd_keywords):
        """Analyzes commits for NO SATD by checking if the commit message does contain any of the specified SATD keywords.
        Args:
          start_date: The start date of the date range to analyze commits within.
          end_date: The end date of the date range to analyze commits within.
          satd_keywords: A list of SATD keywords to search for in commit messages.
        Returns:
          A tuple containing two sets:
            * A set of commit hashes that contain SATD keywords in their commit messages.
            * A dictionary mapping commit hashes to their associated commit messages.
        """
        # Initialize sets to store commits and their associated SATD keywords
        commits_with_satd = set()
        dict_commit_msg = {}

        # Traverse commits within the specified date range
        print('Aguarde...')
        my_traverser_commits = Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits()
        total_commits = len(list(my_traverser_commits))

        for commit in tqdm.tqdm(Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits(), total=total_commits, desc="Progress SATD message commit analysis"):
          if self.testa_keywords_not_in_text(list(satd_keywords), commit.msg) is not None:
            commits_with_satd.add(commit.hash)
            dict_commit_msg[commit.hash] = commit.msg

        return commits_with_satd, dict_commit_msg

    def analyze_commit_diffs_for_satd(self, start_date, end_date, satd_keywords):
        """Analyzes commit diffs for SATD by checking if any of the specified SATD keywords are found in any of the added lines of the diff.
        Args:
          start_date: The start date of the date range to analyze commit diffs within.
          end_date: The end date of the date range to analyze commit diffs within.
          satd_keywords: A list of SATD keywords to search for in commit diffs.
        Returns:
          A dictionary mapping commit hashes to lists of tuples, where each tuple contains a SATD keyword and the corresponding line of the diff where the keyword was found.
        """
        # Initialize a dictionary to store commit hashes and their associated SATD keywords and diff content
        dict_commit_diffs = {}

        # Traverse commits within the specified date range
        print('Aguarde...')
        my_traverser_commits = Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits()
        total_commits = len(list(my_traverser_commits))

        for commit in tqdm.tqdm(Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits(), total=total_commits, desc="Progress SATD diff commit analysis"):
            list_keywords_by_commit = []
            list_diff_content_by_commit = []

            for modification in commit.modified_files:
                for line in modification.diff_parsed['added']:
                    valor_linha = line[0]
                    conteudo_linha = line[1]

                    for keyword in satd_keywords:
                        if SATDCommitAnalyzer.is_java_comment(conteudo_linha):
                            if keyword in conteudo_linha:
                                list_keywords_by_commit.append(keyword)
                                list_diff_content_by_commit.append(conteudo_linha)

            if list_keywords_by_commit:
                elemento = commit.msg, commit.lines, commit.files, list_keywords_by_commit, list_diff_content_by_commit
                dict_commit_diffs[commit.hash] = elemento

        return dict_commit_diffs

    def analyze_commit_diffs_for_no_satd(self, start_date, end_date, satd_keywords):
        """Analyzes commit diffs for NO SATD by checking if any of the specified SATD keywords are found in any of the added lines of the diff.
        Args:
          start_date: The start date of the date range to analyze commit diffs within.
          end_date: The end date of the date range to analyze commit diffs within.
          satd_keywords: A list of SATD keywords to search for in commit diffs.
        Returns:
          A dictionary mapping commit hashes to lists of tuples, where each tuple contains a SATD keyword and the corresponding line of the diff where the keyword was found.
        """
        # Initialize a dictionary to store commit hashes and their associated SATD keywords and diff content
        dict_commit_diffs = {}

        # Traverse commits within the specified date range
        print('Aguarde...')
        my_traverser_commits = Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits()
        total_commits = len(list(my_traverser_commits))

        for commit in tqdm.tqdm(Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits(), total=total_commits, desc="Progress SATD diff commit analysis"):
            list_diff_content_by_commit = []

            for modification in commit.modified_files:
                for line in modification.diff_parsed['added']:
                    valor_linha = line[0]
                    conteudo_linha = line[1]
                    if SATDCommitAnalyzer.is_java_comment(conteudo_linha):
                        if self.testa_keywords_not_in_text(list(satd_keywords), conteudo_linha) is not None:
                            list_diff_content_by_commit.append(conteudo_linha)
            dict_commit_diffs[commit.hash] = commit.msg, commit.lines, commit.files,list_diff_content_by_commit
        return dict_commit_diffs

    def total_of_commits(self, start_date, end_date):
        # Traverse commits within the specified date range
        print('Aguarde...')
        my_traverser_commits = Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits()
        total_commits = len(list(my_traverser_commits))
        lista_hash_commits = []
        for commit in tqdm.tqdm(Repository(self.path_to_repository, since=start_date, to=end_date).traverse_commits(), total=total_commits, desc="Progress messagem commit analysis"):
            lista_hash_commits.append(commit.hash)
        return total_commits, lista_hash_commits

    def testa_keywords_not_in_text(self,keywords, my_text):
      qtd_itens = len(keywords)
      lista_checa = []
      for i, each in enumerate(keywords):
        if keywords[i] not in my_text:
          lista_checa.append(0)
      if len(lista_checa)==qtd_itens and sum(lista_checa) == 0:
        return my_text
      return None

# %% [markdown]
# # Clona o repositório

# %%
#!rm -rf activemq

# %%
print(f'Clona o repositório : {url_to_repository}')
# !git clone $MY_REPOSITORY
# Out:
# Clona o repositório : https://github.com/apache/activemq.git
# Cloning into 'activemq'...
# remote: Enumerating objects: 237770, done.
# remote: Counting objects: 100% (4536/4536), done.
# remote: Compressing objects: 100% (2155/2155), done.
# remote: Total 237770 (delta 1946), reused 4177 (delta 1726), pack-reused 233234
# Receiving objects: 100% (237770/237770), 61.64 MiB | 8.04 MiB/s, done.
# Resolving deltas: 100% (114944/114944), done.

# %% [markdown]
# # Analisa commits

# %%
start_date = datetime(2009, 1, 1, 0, 0, 0)
end_date = datetime(2023, 10, 4, 0, 0, 0)
my_satd_commit_analyzer = SATDCommitAnalyzer(path_to_repository)

# %% [markdown]
# ## Analyzes commit messages
#
# Analisa todas as mensagens dos commits entre 1/01/2009 e 4/10/2023 do ActiveMQ que contem as Keywords coletadas da literatura.

# %%
commits_msg_with_satd, dict_commit_msg = my_satd_commit_analyzer.analyze_commits_for_satd(start_date, end_date, final_satd_keywords)
# Out:
# Aguarde...
# Progress SATD message commit analysis: 100%|██████████| 7941/7941 [00:02<00:00, 3312.78it/s]

# %% [markdown]
# ### Analyzes commit messages without SATD

# %%
commits_with_no_satd, dict_commit_msg_no_satd = my_satd_commit_analyzer.analyze_commits_for_no_satd(start_date, end_date, final_satd_keywords)
# Out:
# Aguarde...
# Progress SATD message commit analysis: 100%|██████████| 7941/7941 [00:02<00:00, 2680.65it/s]

# %% [markdown]
# ## Analyzes commit diffs
#
# Analisa todos os diffs (added) dos commits entre 1/01/2009 e 4/10/2023 do ActiveMQ que contem as SATD.

# %%
dict_commit_diffs = my_satd_commit_analyzer.analyze_commit_diffs_for_satd(start_date, end_date, final_satd_keywords)
# Out:
# Aguarde...
# Progress SATD diff commit analysis: 100%|██████████| 7941/7941 [07:04<00:00, 18.73it/s]

# %% [markdown]
# ### Cria um dataframe para representar o resultado da análise de SATD Keywords dos Diffs dos commits

# %%
l_commits, l_msgs, l_lines, l_files, l_comments = [], [], [], [], []

for k, v in dict_commit_diffs.items():
    l_commits.append(k)
    l_msgs.append(v[0])
    l_lines.append(v[1])
    l_files.append(v[2])
    l_comments.append(v[3])

dict_commit_diffs_aux = {
    'commits': l_commits,
    'msg': l_msgs,
    'lines': l_lines,
    'files': l_files,
    'comments': l_comments
}

df_commit_diffs_aux = pd.DataFrame(dict_commit_diffs_aux)
df_commit_diffs_aux
# Out:
#                                       commits  \
# 0    e2c83d6fb6355dcf65821268cd1843ff603dc5f9
# 1    8b9e755035c0cd901da6083f48f53b9ad2f763e4
# 2    f1d59cd2cd236dee5d78520a0c607ef289a9dfa9
# 3    1f00a395f895751cc8d50eccd335b004c0f77012
# 4    977393d9e74364c21260f00d2fe0e314c77f9afa
# ..                                        ...
# 937  5473ea58e523db0410e743369aead7e5b3bf4342
# 938  af07efe27daff274d3cdf9b51174533626731810
# 939  65267a9a158938f3e6c1c2dcec7610dec607c55a
# 940  90fbd9098bacae2f0150fad33b7c15f1ed42c5cb
# 941  09ae41adec4b538ea372e00e95e47df06e669efe
#
#                                                    msg  lines  files  \
# 0    Remove some dangerous method calls from the co...     71      1
# 1    resolve AMQ-2062 - add setExceptionListener to...     25      1
# 2    add test case to exercise producerFlowControl ...    163      2
# 3    AMQ-2078 extend transaction tests to xa in ra\...    349      4
# 4    fix for http://issues.apache.org/activemq/brow...    170      4
# ..                                                 ...    ...    ...
# 937  [AMQ-9239] jakarta.jms - activemq-ra, activemq...   1008     42
# 938   [AMQ-9239] jakarta.jms - activemq-spring changes   1253     26
# 939  [AMQ-9239] jakarta.jms - activemq-unit-tests c...   9051    807
# 940  [AMQ-9239] jakarta.jms - activemq-web-console,...    536     63
# 941         [AMQ-8325] JMS 2.0 XA supported operations    361      9
#
#                                               comments
# 0                                  [TODO, constructor]
# 1                    [exception, exception, exception]
# 2                         [exception, test, exception]
# 3                    [test, test, test, test, comment]
# 4                                               [test]
# ..                                                 ...
# 937  [TODO, TODO, TODO, TODO, TODO, TODO, TODO, TOD...
# 938  [TODO, TODO, TODO, TODO, TODO, TODO, support f...
# 939                                            [FIXME]
# 940                            [TODO, API, annotation]
# 941                                             [test]
#
# [942 rows x 5 columns]

# %%
df_activemq_commits_issues_yes_ai = df_commit_diffs_aux[df_commit_diffs_aux.commits.isin(lista_activemq_commits_issues_yes_ai)]
df_activemq_commits_issues_yes_ai
# Out:
#                                       commits  \
# 25   08aecbee6e9754e696f3bdf64634263dc73cb5c5
# 26   132f662209f7e25a1d9c240fdddcf61e0ed1226c
# 94   83128fc45b65aff89ba78596a158a01960029742
# 150  306f8a0774b7892ba1b572e1faea15847711b4ba
# 188  8bf987b134bd827b93ed8157b323bc3bd2d8a82e
# 194  cb967831d62231694a003cf5d9468da2e890d36d
# 207  b9045dba98f053e31fb93922978334b126ad146b
# 255  8ce077800fdfa5aca341734cbc4ec69e5e645c61
# 263  332c35ca18fba9316480160d4d294abda4e680bc
# 270  cb1b92bf58e2631077a31b97cc8087bb35605a03
# 385  30f531d7414f4a19c26e56c236eea08a77012a8f
# 488  c2eb4863a8cc4de79a7f63fea915bf9397981bb8
# 495  2bbfbcfb29463f9723a0efe548d46af7ddb3fbb6
# 550  433912f79a3ffb2323bc0060a980e77122f9a204
# 630  eb6c0826311a876769e56029dc1e261ee7519db5
# 844  6e468b4540754cad5cd30de373cadc026c998669
# 846  57a6f2373eb7609ce4ab7cadcd7d38889414a24c
# 874  de3f77063fa579159184d23ac98df97e80d63327
#
#                                                    msg  lines  files  \
# 25   partial fix for AMQ2149|http://issues.apache.o...    290      6
# 26   resolve AMQ-2149|https://issues.apache.org/act...    326     21
# 94   https://issues.apache.org/activemq/browse/AMQ-...    236      3
# 150  resolve https://issues.apache.org/activemq/bro...    231      8
# 188  https://issues.apache.org/jira/browse/AMQ-3177...   4738    570
# 194  https://issues.apache.org/jira/browse/AMQ-3188...    463     12
# 207  https://issues.apache.org/jira/browse/AMQ-3253...    327     15
# 255  https://issues.apache.org/jira/browse/AMQ-3551...    168      4
# 263  https://issues.apache.org/jira/browse/AMQ-3384...    154      5
# 270  apply patch and add test for: https://issues.a...    438      5
# 385  Changes for https://issues.apache.org/jira/bro...    748     16
# 488  Fix for https://issues.apache.org/jira/browse/...     70      3
# 495  Fix for https://issues.apache.org/jira/browse/...    509      3
# 550  https://issues.apache.org/jira/browse/AMQ-5271...   1202     17
# 630  https://issues.apache.org/jira/browse/AMQ-5735...    181     11
# 844  AMQ-6947 - Update Queue metrics on expiration\...     13      1
# 846  AMQ-6854 - ensure non null return in the event...    178      2
# 874  AMQ-7234 - fix up memory usage wait timeout su...    163      5
#
#                                               comments
# 25                                             [debug]
# 26                                              [test]
# 94                                         [exception]
# 150                                   [update, update]
# 188                     [test, test, test, test, test]
# 194                       [update, test, dependencies]
# 207                                         [fix, fix]
# 255                                             [test]
# 263                                              [fix]
# 270                                     [test, design]
# 385                                 [exception, debug]
# 488                                             [test]
# 495                                            [debug]
# 550  [update, implementation, performance, implemen...
# 630                                             [hack]
# 844                                   [update, update]
# 846                                             [test]
# 874                                 [test, test, hack]

# %%
df_activemq_commits_issues_yes_ai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 25 to 874
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   commits   18 non-null     object
#  1   msg       18 non-null     object
#  2   lines     18 non-null     int64
#  3   files     18 non-null     int64
#  4   comments  18 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 864.0+ bytes

# %%
p_commits_com_yes_ai = round(len(df_activemq_commits_issues_yes_ai)/len(lista_activemq_commits_issues_yes_ai), 3)
print(f'% de commits com Impacto Arquitetural e SATD: {p_commits_com_yes_ai}')
# Out:
# % de commits com Impacto Arquitetural e SATD: 0.316

# %%
round(df_activemq_commits_issues_yes_ai.describe(), 2)
# Out:
#          lines   files
# count    18.00   18.00
# mean    579.72   39.28
# std    1074.39  132.58
# min      13.00    1.00
# 25%     170.50    3.25
# 50%     263.00    5.50
# 75%     456.75   14.25
# max    4738.00  570.00

# %%
df_activemq_commits_issues_yes_ai.to_excel('activemq_commits_issues_yes_ai_satd.xlsx',index=False)

# %% [markdown]
# # Analisa todos os diffs (added) dos commits entre ? e 4/10/2023 do ActiveMQ SEM as SATD.

# %%
dict_commit_diffs_no_satd = my_satd_commit_analyzer.analyze_commit_diffs_for_no_satd(start_date, end_date, final_satd_keywords)
# Out:
# Aguarde...
# Progress SATD diff commit analysis: 100%|██████████| 7941/7941 [03:00<00:00, 43.88it/s]

# %%
l_commits_no_satd, l_msg_no_satd, l_lines_no_satd, l_files_no_satd, l_comments_no_satd = [], [], [], [], []

for k, v in dict_commit_diffs_no_satd.items():
  if len(v[3]) > 0:
    l_commits_no_satd.append(k)
    l_msg_no_satd.append(v[0])
    l_lines_no_satd.append(v[1])
    l_files_no_satd.append(v[2])
    l_comments_no_satd.append(v[3])

dict_commit_diffs_aux_no_satd = {
    'commits': l_commits_no_satd,
    'msg': l_msg_no_satd,
    'lines': l_lines_no_satd,
    'files': l_files_no_satd,
    'comments': l_comments_no_satd
}

df_commit_diffs_aux_no_satd = pd.DataFrame(dict_commit_diffs_aux_no_satd)

df_commit_diffs_aux_no_satd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2836 entries, 0 to 2835
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   commits   2836 non-null   object
#  1   msg       2836 non-null   object
#  2   lines     2836 non-null   int64
#  3   files     2836 non-null   int64
#  4   comments  2836 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 110.9+ KB

# %%
df_commit_diffs_aux_no_satd
# Out:
#                                        commits  \
# 0     78c002f5686b5ab724f0943b199b4f9ebc45ea66
# 1     f62737be7caa75e179dee1f6b081632668dd06af
# 2     d8c14e075ffc54385c2a6817758e9afd100441ba
# 3     e2c83d6fb6355dcf65821268cd1843ff603dc5f9
# 4     34acbdc154fc5dc6d484cbc075e8394843f97b96
# ...                                        ...
# 2831  e10d457868f851af96e9aa899c8840c0d5514d76
# 2832  9f374dfcb50729693ae1ee55d58bfea27fef1c0a
# 2833  09ae41adec4b538ea372e00e95e47df06e669efe
# 2834  538b04aa0c18f61cd47b261c7372a3e559c2ca0e
# 2835  578d86d726d80715825e5f927ef8af50e181d754
#
#                                                     msg  lines  files  \
# 0     AMQ-2052 more better fixes of where to make th...     38      4
# 1     Moving stuff around so that activemq-core can ...   4462     42
# 2     make use of 'this' more consistent and fix a c...     24      1
# 3     Remove some dangerous method calls from the co...     71      1
# 4     minor generics, import, and javadoc cleanup\n\...     12      1
# ...                                                 ...    ...    ...
# 2831          [AMQ-9239] jakarta.jms - assembly changes    262     40
# 2832  [AMQ-9301] Add additional fields to o.a.active...     32      2
# 2833         [AMQ-8325] JMS 2.0 XA supported operations    361      9
# 2834  [AMQ-9255] Initialize the transient field of t...    167      3
# 2835  [AMQ-9315] Add connectedTimestamp to Connectio...     50      7
#
#                                                comments
# 0     [     * @param type "PERSISTENT" or "VM",     ...
# 1     [  //| option java_implments = "org.apache.act...
# 2     [     * @param maxItems maximum number of mess...
# 3     [     * @param broker Broker for this cursor, ...
# 4     [     * @param context broker context,      * ...
# ...                                                 ...
# 2831  [        // AMQ-9239 - setEnv doesn't work w/ ...
# 2832  [    /**,      * @return true if the Connectio...
# 2833  [/**,  * Licensed to the Apache Software Found...
# 2834  [    /**,      * Initialize the transient fiel...
# 2835  [    /**,      * Returns the time in ms since ...
#
# [2836 rows x 5 columns]

# %%
df_activemq_commits_issues_no_ai_no_satd = df_commit_diffs_aux_no_satd[df_commit_diffs_aux_no_satd.commits.isin(lista_activemq_commits_issues_no_ai)]
df_activemq_commits_issues_no_ai_no_satd
# Out:
#                                        commits  \
# 5     07b6a38336a62913d42817a89cdc821a89419b7f
# 27    3b08860f10a12b8753e24756cf66f4a8d66b270e
# 56    184761a119ae684a910bed41bc0f81bc2334fdb4
# 94    62e1abfb902ac48741481bd0d80783ecef9e79a4
# 136   dbe847e0dade437ba678299f62e899f61b95a3e9
# 153   ced6909078435963f9e1a1e1be84281a1c48eb62
# 181   c4597840128288f8e2722ab0b6e2bc9ee12b3e85
# 226   5eb274d08d038ae2ce10929f4562f390ab09a4d0
# 468   145c80a298c71f20ae080b1feca715f153b89881
# 525   227ed96df0228df001385768a94ec846390c8956
# 940   a1d5ff03169024fe486b96378f5e8409b6a98fd9
# 946   beda82ad5a854fafa2a9847fe93991071f517f2e
# 959   f5dcc9dfbf6635ec70916376afcb7640396def4a
# 980   5cd9ebaeb7f82e2828e6ccf0931b12aab51dddab
# 153   fix for https://issues.apache.org/activemq/bro...    416     16
# 181   Fix for https://issues.apache.org/activemq/bro...    281      3
# 226   resolve https://issues.apache.org/activemq/bro...    203      5
# 468   https://issues.apache.org/activemq/browse/AMQ-...    152     10
# 525   https://issues.apache.org/activemq/browse/AMQ-...    351      3
# 940   fix for: for: https://issues.apache.org/jira/b...     19      1
# 946   https://issues.apache.org/jira/browse/AMQ-3706...    299      4
# 959   fix for: https://issues.apache.org/jira/browse...    287     13
# 980   fis for: https://issues.apache.org/jira/browse...     72      3
# 1039  fix for: https://issues.apache.org/jira/browse...     45      1
# 1050  https://issues.apache.org/jira/browse/AMQ-3912...     94      2
# 1064  https://issues.apache.org/jira/browse/AMQ-3935...    220      2
# 1104  AMQ-4008: Fixed MDC leak during shutting down ...     44      2
# 1145  fix for: https://issues.apache.org/jira/browse...    826     10
# 1227  https://issues.apache.org/jira/browse/AMQ-4181...    260      7
# 1255  apply fix for: https://issues.apache.org/jira/...    635     11
# 1282  fixes: https://issues.apache.org/jira/browse/A...    120      1
# 1294  https://issues.apache.org/jira/browse/AMQ-4248...    265      6
# 1309  https://issues.apache.org/jira/browse/AMQ-4276...    918     17
# 1313  https://issues.apache.org/jira/browse/AMQ-4276...      7      1
# 1366  Added at test case and fix for AMQ-4351.\n\nAv...    241      2
# 1388  https://issues.apache.org/jira/browse/AMQ-3706...    100      3
# 1394  https://issues.apache.org/jira/browse/AMQ-4483...     92     11
# 1396  fix for: https://issues.apache.org/jira/browse...     85      3
# 1407  Fix and test for: https://issues.apache.org/ji...    232      4
# 1418  fix for: https://issues.apache.org/jira/browse...    172      2
# 1511  https://issues.apache.org/jira/browse/AMQ-4656...     50      7
# 1687  https://issues.apache.org/jira/browse/AMQ-4754...    217      5
# 1900  https://issues.apache.org/jira/browse/AMQ-4107...     43      2
# 1948  https://issues.apache.org/jira/browse/AMQ-5640...    188      2
# 2061  https://issues.apache.org/jira/browse/AMQ-5745...    514     21
# 2138  https://issues.apache.org/jira/browse/AMQ-6014...    212      3
# 2155  https://issues.apache.org/jira/browse/AMQ-6050...    381      4
# 2208  https://issues.apache.org/jira/browse/AMQ-6128...    269      5
# 2209  https://issues.apache.org/jira/browse/AMQ-6129...    201      8
# 2223  https://issues.apache.org/jira/browse/AMQ-6164...     73      4
# 2294  https://issues.apache.org/jira/browse/AMQ-6286...    239      7
# 2306  AMQ-4181 - revert mod to testQueueBrowserWith2...     46      2
# 2386  https://issues.apache.org/jira/browse/AMQ-6422...    171      9
# 2411  https://issues.apache.org/jira/browse/AMQ-6465...     92      2
# 2418  https://issues.apache.org/jira/browse/AMQ-6477...    251      8
# 2461  https://issues.apache.org/jira/browse/AMQ-6555...    143      5
# 2470  https://issues.apache.org/jira/browse/AMQ-6579...    129      2
# 2547  [AMQ-6847] pause dispatch for message move to ...     78      2
# 2548  [AMQ-6847] limit the retry loop to one iterati...     20      2
# 2718           AMQ-7513 - Fix http://activemq.org links     28     12
# 2755  [AMQ-8413] Add remoteUserName and remotePasswo...     79      4
# 2785  AMQ-9153: Fix slow consumer advisory for queue...     53      2
# 2788  AMQ-9157 - Add a new optional advisory for dis...    273     15
# 2790  AMQ-9157 - Include consumer id as part of Disp...     44     12
# 2801  AMQ-9202 - Make sure Reentrant locks are acqui...     86      3
# 2818  AMQ-9262 - Fix network subscriptions for compo...    619      5
#
#                                                comments
# 5     [     * @param context connection context,    ...
# 27    [    // Always walk list in reverse order.,   ...
# 56    [        // Set prefetch to 1,         // the ...
# 94    [        // clear the state,     \t//send and ...
# 136   [                            // drop message w...
# 153   [/**,  */,   /** {@inheritDoc} */,   /** {@inh...
# 181   [/**,  * Licensed to the Apache Software Found...
# 226   [            // if maximumPendingMessages is s...
# 468   [    /**,      * Sets hooks to be executed whe...
# 525   [                                // Dispatch i...
# 940   [            // If optimize dispatch is on or ...
# 946   [    /**,      *,      * @throws Exception,   ...
# 959   [    /**,      * Should MBeans that support sh...
# 980                                                [ *]
# 1039  [    /**,      * Performs a timed wait on the ...
# 1050  [/**,  * Licensed to the Apache Software Found...
# 1064  [        // verify second batch is visible to ...
# 1104  [            // throw new IllegalStateExceptio...
# 1145  [            // strip off server side query pa...
# 1227  [                        // are we done browsi...
# 1255  [    // to other jms messaging systems,       ...
# 1282  [                        // find first publish...
# 1294  [                    // Since the message gets...
# 1309  [/**,  * Licensed to the Apache Software Found...
# 1313  [            // ensure not available for condu...
# 1366  [/**,  * https://issues.apache.org/jira/browse...
# 1388  [/**,  * Licensed to the Apache Software Found...
# 1394  [    /**,      * @return true if this is dead ...
# 1396  [            // Synchronized to DispatchLock i...
# 1407  [            // our own bridges.,      *,     ...
# 1418  [/**,  * Licensed to the Apache Software Found...
# 1511  [                    // If nothing was in the ...
# 1687  [    /**,      * @return the current number of...
# 1900  [                // if maximumPendingMessages ...
# 1948  [/**,  * Licensed to the Apache Software Found...
# 2061  [ *,  *,         // should we append any syste...
# 2138  [                        // not sure why pendi...
# 2155  [                        //remove subscriber f...
# 2208  [/**,  * Licensed to the Apache Software Found...
# 2209  [                                             ...
# 2223  [                    // we may have a store in...
# 2294  [            // insert this new list at root, ...
# 2306  [        // a browse is a snapshot - only guar...
# 2386  [                    // reset delivery counter...
# 2411  [            //AMQ-6465 - Need to decrement th...
# 2418  [            //Clear the unmarshalled state if...
# 2461  [/**,  * Licensed to the Apache Software Found...
# 2470  [/**,  * Licensed to the Apache Software Found...
# 2547                              [        // populate]
# 2548  [        // ensure we deal with a snapshot to ...
# 2718  [ * Creates <a href="https://activemq.apache.o...
# 2755  [        // Hide the password for security rea...
# 2785  [                        //For full consumers ...
# 2788  [    /**,      * Called when message is dispat...
# 2790  [     * @param sub,      * @param sub,        ...
# 2801  [            //acquire the checkpoint lock to ...
# 2818  [            // If we have an entry in composi...

# %%
round(df_activemq_commits_issues_no_ai_no_satd.describe(), 2)
# Out:
#           lines   files
# count     57.00   57.00
# mean     415.95    7.89
# std     1600.08   16.97
# min        7.00    1.00
# 25%       79.00    2.00
# 50%      164.00    4.00
# 75%      265.00    8.00
# max    12202.00  129.00

# %%
df_activemq_commits_issues_no_ai_no_satd.to_excel('activemq_commits_issues_no_ai_no_satd.xlsx',index=False)
